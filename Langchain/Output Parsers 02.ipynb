# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import CommaSeparatedListOutputParser
# Out:
# /opt/anaconda3/envs/langchain_env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
chat = ChatOpenAI(
    model="gpt-4o-mini", 
    seed=365,
    temperature=0,
    max_tokens=100,
)

# %%
message_h=HumanMessage(content="suggest dog names")

# %%
response=chat.invoke([message_h])
response
# Out:
# AIMessage(content='Sure! Here are some dog name suggestions categorized by themes:\n\n### Classic Names\n1. Max\n2. Bella\n3. Charlie\n4. Daisy\n5. Buddy\n\n### Unique Names\n1. Zephyr\n2. Juno\n3. Nimbus\n4. Quasar\n5. Tofu\n\n### Food-Inspired Names\n1. Biscuit\n2. Olive\n3. Peanut\n4. Mocha\n5. Pickles\n\n### Nature-Inspired Names\n1', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 10, 'total_tokens': 110, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f15516a462', 'id': 'chatcmpl-DT0LI6E7dZqsDedxH0K72fZC4SZPr', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019d763c-f42a-7fb3-9abe-105d14442b53-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 100, 'total_tokens': 110, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
list_output_parser=CommaSeparatedListOutputParser()

# %%
response_parsed=list_output_parser.invoke(response)
response_parsed
# Out:
# ['Sure! Here are some dog name suggestions categorized by themes:',
#  '### Classic Names',
#  '1. Max',
#  '2. Bella',
#  '3. Charlie',
#  '4. Daisy',
#  '5. Buddy',
#  '### Unique Names',
#  '1. Zephyr',
#  '2. Juno',
#  '3. Nimbus',
#  '4. Quasar',
#  '5. Tofu',
#  '### Food-Inspired Names',
#  '1. Biscuit',
#  '2. Olive',
#  '3. Peanut',
#  '4. Mocha',
#  '5. Pickles',
#  '### Nature-Inspired Names',
#  '1']

# %%
print(list_output_parser.get_format_instructions())
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
