# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai import ChatOpenAI

from langchain_core.prompts import ChatPromptTemplate
# Out:
# /opt/anaconda3/envs/langchain_env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
chat_template=ChatPromptTemplate.from_messages([('human', 
     "I've recently adopted a {pet} which is {breed} . Could you suggest training tips \n" )])

# %%
chat = ChatOpenAI(model_name = 'gpt-4', 
                  model_kwargs = {'seed':365},
                  temperature = 0,
                  max_tokens = 100)

# %%
chain=chat_template|chat

# %%
chain.invoke({"pet":"dog","breed":"husky"})
# Out:
# AIMessage(content="1. Start Early: Start training your Husky as soon as you bring him home. They are intelligent dogs and can start learning commands and tricks from a young age.\n\n2. Consistency is Key: Huskies are known for their stubbornness, so it's important to be consistent with your training. Use the same commands and rewards each time, and make sure everyone in your household is on the same page.\n\n3. Positive Reinforcement: Always use positive reinforcement when training your Husky.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 24, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-DT8cw97aDHVKNWsJMppd3zWfvleMq', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019d7822-d79f-71a0-9420-92fdff7b45c8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 100, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# %%time
chain.batch([{"pet":"dog","breed":"husky"},{"pet":"dragon","breed":"night fury"}])
# Out:
# CPU times: user 16.6 ms, sys: 3.33 ms, total: 20 ms
# Wall time: 5.5 s
# [AIMessage(content="1. Start Early: Start training your Husky as soon as you bring him home. Huskies are intelligent and learn quickly, but they also have a strong will and can be stubborn. The earlier you start, the better.\n\n2. Consistency is Key: Be consistent with your commands and training. If you allow your Husky to do something once, he will think it's always allowed. Make sure everyone in your household is on the same page with training.\n\n3. Positive Reinforcement", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 24, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-DT8iMsUH6Dzpl2EVzJMsJa45H7d2D', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019d7828-083a-7432-9cc0-4837f9a56cd5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 100, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='Training a dragon, especially a Night Fury, is no small task. Here are some tips to help you:\n\n1. Establish Trust: Night Furies are intelligent and sensitive creatures. They need to trust you before they can be trained. Spend time with your dragon, talk to it, and show it that you mean no harm.\n\n2. Positive Reinforcement: Like any other pet, dragons respond well to positive reinforcement. Reward your dragon with treats or praise when it behaves well or follows a command.\n\n', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 24, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-DT8iNswU1Bzl7vcWsp1A5EbSJqMaD', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019d7828-083d-70f3-9852-b0ff4e0aba59-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 100, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
# %%time
chain.invoke({"pet":"dog","breed":"husky"})
# Out:
# CPU times: user 9.22 ms, sys: 2.05 ms, total: 11.3 ms
# Wall time: 4.61 s
# AIMessage(content="1. Start Early: Start training your Husky as soon as you bring him home. They are intelligent dogs and can start learning commands and tricks from a young age.\n\n2. Consistency is Key: Huskies are known for their stubbornness, so it's important to be consistent with your training. Use the same commands and rewards each time, and make sure everyone in your household is on the same page.\n\n3. Positive Reinforcement: Always use positive reinforcement when training your Husky.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 24, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-DT8iSm1xQBHettjWAwVrH7kVyJI6o', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019d7828-1dbf-75c1-b817-39c88a387336-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 100, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# %%time
chain.invoke({"pet":"dragon","breed":"night fury"})
# Out:
# CPU times: user 9.86 ms, sys: 2.03 ms, total: 11.9 ms
# Wall time: 5.94 s
# AIMessage(content='Training a dragon, especially a Night Fury, is no small task. Here are some tips to help you:\n\n1. Establish Trust: Night Furies are intelligent and sensitive creatures. They need to trust you before they can be trained. Spend time with your dragon, talk to it, and show it that you mean no harm.\n\n2. Positive Reinforcement: Like any other pet, dragons respond well to positive reinforcement. Reward your dragon with treats or praise when it behaves well or follows a command.\n\n', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 24, 'total_tokens': 124, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-DT8iXr4CFt18kTNbIiT54sdZCsMoS', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019d7828-2fca-77d0-bf9b-1e84d9b1139d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 100, 'total_tokens': 124, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
